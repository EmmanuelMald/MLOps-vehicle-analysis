# %% [markdown]
# # Vehicle Autonomy Estimator

# %% [markdown]
# This notebook aims to develop a ML model that can estimate the autonomy of a vehicle (km/L) based on some characteristics

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_regression
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler
from sklearn.linear_model import LinearRegression 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
import joblib

pd.set_option("display.max_columns",None)

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# There's already a cleaned dataset stored in this repo, the main process of cleaning it can be checked in the *data_sources/data_preparation.ipynb* notebook

# %%
data = pd.read_parquet(r"../../../data_sources/vehicle_data_prepared.parquet")

# %%
data.query("combined_kmpl_for_fuel_type2 != 0").sort_values("combined_kmpl_for_fuel_type1", ascending=False)
# Out:
#             make    basemodel                        model  year  \
# 21117     Toyota  Prius Prime                  Prius Prime  2019
# 18085     Toyota  Prius Prime                  Prius Prime  2021
# 22929     Toyota  Prius Prime                  Prius Prime  2022
# 23400     Toyota  Prius Prime                  Prius Prime  2017
# 8901      Toyota  Prius Prime                  Prius Prime  2018
# ...          ...          ...                          ...   ...
# 23343       Ford         F150     F150 Dual-fuel 2WD (CNG)  2002
# 9515        Ford         F150     F150 Dual-fuel 4WD (CNG)  2002
# 18791       Ford         F150     F150 Dual-fuel 2WD (CNG)  2001
# 28035       Ford         F150     F150 Dual-fuel 4WD (CNG)  2001
# 4928   Chevrolet    Silverado  Silverado 2500 2WD (Bifuel)  2003
#
#                vehicle_size_class  cylinders  engine_displacement_liters  \
# 21117                Midsize Cars        4.0                         1.8
# 18085                Midsize Cars        4.0                         1.8
# 22929                Midsize Cars        4.0                         1.8
# 23400                Midsize Cars        4.0                         1.8
# 8901                 Midsize Cars        4.0                         1.8
# ...                           ...        ...                         ...
# 23343  Standard Pickup Trucks 2WD        8.0                         5.4
# 9515   Standard Pickup Trucks 4WD        8.0                         5.4
# 18791  Standard Pickup Trucks 2WD        8.0                         5.4
# 28035  Standard Pickup Trucks 4WD        8.0                         5.4
# 4928   Standard Pickup Trucks 2WD        8.0                         6.0
#
#        t_charger  s_charger             electric_motor  \
# 21117      False      False  22 and 53 kW AC Induction
# 18085      False      False  22 and 53 kW AC Induction
# 22929      False      False  22 and 53 kW AC Induction
# 23400      False      False  16 and 37 kW AC Induction
# 8901       False      False  16 and 37 kW AC Induction
# ...          ...        ...                        ...
# 23343      False      False                       None
# 9515       False      False                       None
# 18791      False      False                       None
# 28035      False      False                       None
# 4928       False      False                       None
#
#                            transmission                       drive  \
# 21117  Automatic (variable gear ratios)           Front-Wheel Drive
# 18085  Automatic (variable gear ratios)           Front-Wheel Drive
# 22929  Automatic (variable gear ratios)           Front-Wheel Drive
# 23400  Automatic (variable gear ratios)           Front-Wheel Drive
# 8901   Automatic (variable gear ratios)           Front-Wheel Drive
# ...                                 ...                         ...
# 23343                   Automatic 4-spd            Rear-Wheel Drive
# 9515                    Automatic 4-spd  4-Wheel or All-Wheel Drive
# 18791                   Automatic 4-spd            Rear-Wheel Drive
# 28035                   Automatic 4-spd  4-Wheel or All-Wheel Drive
# 4928                    Automatic 4-spd            Rear-Wheel Drive
#
#        start_stop                    fuel_type        fuel_type1   fuel_type2  \
# 21117        True  Regular Gas and Electricity  Regular Gasoline  Electricity
# 18085        True  Regular Gas and Electricity  Regular Gasoline  Electricity
# 22929        True  Regular Gas and Electricity  Regular Gasoline  Electricity
# 23400        True  Regular Gas and Electricity  Regular Gasoline  Electricity
# 8901         True  Regular Gas and Electricity  Regular Gasoline  Electricity
# ...           ...                          ...               ...          ...
# 23343       False      Gasoline or natural gas  Regular Gasoline  Natural Gas
# 9515        False      Gasoline or natural gas  Regular Gasoline  Natural Gas
# 18791       False      Gasoline or natural gas  Regular Gasoline  Natural Gas
# 28035       False      Gasoline or natural gas  Regular Gasoline  Natural Gas
# 4928        False      Gasoline or natural gas  Regular Gasoline  Natural Gas
#
#        phev_blended  city_electricity_consumption_kwhpkm  \
# 21117          True                            14.291573
# 18085          True                            14.291573
# 22929          True                            14.291573
# 23400          True                            14.291573
# 8901           True                            14.291573
# ...             ...                                  ...
# 23343         False                             0.000000
# 9515          False                             0.000000
# 18791         False                             0.000000
# 28035         False                             0.000000
# 4928          False                             0.000000
#
#        city_kmpl_for_fuel_type1  city_kmpl_for_fuel_type2  \
# 21117                  19.47033                 51.330870
# 18085                  19.47033                 51.330870
# 22929                  19.47033                 51.330870
# 23400                  19.47033                 51.330870
# 8901                   19.47033                 51.330870
# ...                         ...                       ...
# 23343                   3.54006                  3.540060
# 9515                    3.54006                  3.540060
# 18791                   3.54006                  3.540060
# 28035                   3.54006                  3.540060
# 4928                    3.54006                  3.186054
#
#        highway_electricity_consumption_kwhpkm  highway_kmpl_for_fuel_type1  \
# 21117                               17.398437                    18.762318
# 18085                               17.398437                    18.762318
# 22929                               17.398437                    18.762318
# 23400                               17.398437                    18.762318
# 8901                                17.398437                    18.762318
# ...                                       ...                          ...
# 23343                                0.000000                     4.956084
# 9515                                 0.000000                     4.956084
# 18791                                0.000000                     4.956084
# 28035                                0.000000                     4.956084
# 4928                                 0.000000                     3.894066
#
#        highway_kmpl_for_fuel_type2  combined_electricity_consumption_kwhpkm  \
# 21117                    42.834726                                15.534318
# 18085                    42.834726                                15.534318
# 22929                    42.834726                                15.534318
# 23400                    42.834726                                15.534318
# 8901                     42.834726                                15.534318
# ...                            ...                                      ...
# 23343                     4.602078                                 0.000000
# 9515                      4.602078                                 0.000000
# 18791                     4.602078                                 0.000000
# 28035                     4.602078                                 0.000000
# 4928                      3.894066                                 0.000000
#
#        combined_kmpl_for_fuel_type1  combined_kmpl_for_fuel_type2  \
# 21117                     19.116324                     47.082798
# 18085                     19.116324                     47.082798
# 22929                     19.116324                     47.082798
# 23400                     19.116324                     47.082798
# 8901                      19.116324                     47.082798
# ...                             ...                           ...
# 23343                      3.894066                      3.894066
# 9515                       3.894066                      3.894066
# 18791                      3.894066                      3.894066
# 28035                      3.894066                      3.894066
# 4928                       3.540060                      3.540060
#
#        hours_to_charge_at_120v  hours_to_charge_at_240v  \
# 21117                      0.0                      2.0
# 18085                      0.0                      2.0
# 22929                      0.0                      2.0
# 23400                      0.0                      2.0
# 8901                       0.0                      2.0
# ...                        ...                      ...
# 23343                      0.0                      0.0
# 9515                       0.0                      0.0
# 18791                      0.0                      0.0
# 28035                      0.0                      0.0
# 4928                       0.0                      0.0
#
#        co2_tailpipe_for_fuel_type1_gpkm  co2_tailpipe_for_fuel_type2_gpkm
# 21117                         48.467073                          0.000000
# 18085                         48.467073                          0.000000
# 22929                         48.467073                          0.000000
# 23400                         48.467073                          0.000000
# 8901                          48.467073                          0.000000
# ...                                 ...                               ...
# 23343                        502.012683                        397.113667
# 9515                         502.012683                        397.113667
# 18791                        502.012683                        397.113667
# 28035                        502.012683                        397.113667
# 4928                         552.213951                        436.825034
#
# [1882 rows x 30 columns]

# %% [markdown]
# Selecting some columns that will be analize and see if has any relation with the target *combined_kmpl_for_fuel_type1* which is the kmpl of a vehicle driving in highway and city

# %%
cols = [
    "make",
    "basemodel",
    "year",
    "vehicle_size_class",
    "cylinders",
    "engine_displacement_liters",
    "t_charger",
    "s_charger",
    "electric_motor",
    "transmission",
    "drive",
    "start_stop",
    "fuel_type",
    "fuel_type1",
    "fuel_type2",
    "phev_blended"
]

# %%
X = data[cols]
Y = data.combined_kmpl_for_fuel_type1

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Im gonna use mutual information to get the most relevant features for the model. as the target is of a continous type, Im gonna use *mutual_info_regression* in sklearn; This model also needs a list of the column's indexes which datatype is categorical and/or ordinal.
#
# This method also requires all the columns to be numeric. So for all ordinal and categorical values, im gonna use the *OrdinalEncoder* in sklearn. As this model is not sensitive to the values of data; instead search for any reduction in the uncertanty of the target value knowing the feature value.
#
# **In this case, all the features are either ordinal or categorical, so all of them can go trough the OrdinalEncoder in order to make this analysis easier**

# %%
encoder = OrdinalEncoder()

# %%
X_encoded = encoder.fit_transform(X)

# %%
X_encoded[:2,:]
# Out:
# array([[ 33., 751.,  17.,   5.,   5.,  25.,   0.,   0., 391.,  19.,   4.,
#           0.,  12.,   6.,   3.,   0.],
#        [ 22., 390.,  17.,   1.,   5.,  30.,   0.,   0., 391.,  21.,   3.,
#           0.,  12.,   6.,   3.,   0.]])

# %%
mut_info_results = mutual_info_regression(X_encoded, Y, discrete_features=list(range(len(X.columns))))

# %%
df_mut_info = pd.DataFrame({
    "feature":X.columns.tolist(),
    "mutual_info_score":mut_info_results
    
},
).sort_values("mutual_info_score",ascending=False)

# %%
df_mut_info
# Out:
#                        feature  mutual_info_score
# 1                    basemodel           1.368696
# 5   engine_displacement_liters           0.897830
# 4                    cylinders           0.654830
# 0                         make           0.436854
# 9                 transmission           0.399305
# 3           vehicle_size_class           0.322091
# 8               electric_motor           0.296249
# 10                       drive           0.265951
# 12                   fuel_type           0.213465
# 13                  fuel_type1           0.176288
# 2                         year           0.110754
# 6                    t_charger           0.055273
# 11                  start_stop           0.046249
# 14                  fuel_type2           0.027671
# 15                phev_blended           0.008952
# 7                    s_charger           0.008129

# %% [markdown]
# 0 < mut_info_score < 0.5 -> medium relation

# %% [markdown]
# Based on this, It will be choosen those features with mut_info_score > 0.5

# %%
selected_features = df_mut_info.query("mutual_info_score >= 0.3").feature.tolist()

# %%
selected_features
# Out:
# ['basemodel',
#  'engine_displacement_liters',
#  'cylinders',
#  'make',
#  'transmission',
#  'vehicle_size_class']

# %% [markdown]
# Looking for any linear relation

# %%
data[selected_features + ["combined_kmpl_for_fuel_type1"]].corr(method="spearman", numeric_only=True).combined_kmpl_for_fuel_type1
# Out:
# engine_displacement_liters     -0.860252
# cylinders                      -0.834432
# combined_kmpl_for_fuel_type1    1.000000
# Name: combined_kmpl_for_fuel_type1, dtype: float64

# %% [markdown]
# ## Training model

# %%
X = data[selected_features]
Y = data.combined_kmpl_for_fuel_type1

# %%
categorical_features = [x for x in X.columns if x not in X._get_numeric_data()]
numeric_features = [x for x in X.columns if x not in categorical_features]

# %%
categorical_features
# Out:
# ['basemodel', 'make', 'transmission', 'vehicle_size_class']

# %%
numeric_features
# Out:
# ['engine_displacement_liters', 'cylinders']

# %%
col_transformer = ColumnTransformer(transformers=[
                                    ("one_hot_cat_vars", OneHotEncoder(handle_unknown="ignore"), categorical_features),
                                    ("ordinal_encoder_num_vars", MinMaxScaler(), numeric_features)
                                    ]
)

# %%
X_processed = col_transformer.fit_transform(X)

# %%
r2_scores = cross_val_score(
    estimator=LinearRegression(),
    X = X_processed,
    y = Y,
    cv = 5,
    scoring = "neg_root_mean_squared_error"
      )
r2_scores *= -1

# %%
r2_scores
# Out:
# array([1.01421876, 1.12274539, 1.14625531, 1.12453354, 1.16784415])

# %%
r2_scores.mean()
# Out:
# np.float64(1.1151194291147533)

# %%
model = Pipeline(steps=
                 [("data_processing", col_transformer),
                 ("model", LinearRegression())]    
                 )

model.fit(X, Y)
# Out:
# Pipeline(steps=[('data_processing',
#                  ColumnTransformer(transformers=[('one_hot_cat_vars',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['basemodel', 'make',
#                                                    'transmission',
#                                                    'vehicle_size_class']),
#                                                  ('ordinal_encoder_num_vars',
#                                                   MinMaxScaler(),
#                                                   ['engine_displacement_liters',
#                                                    'cylinders'])])),
#                 ('model', LinearRegression())])

# %% [markdown]
# ## Saving the model

# %%
joblib.dump(model, "../model/autonomy_estimator.joblib")
# Out:
# ['../model/autonomy_estimator.joblib']

# %% [markdown]
# ## Testing the model

# %%
model = joblib.load("../model/autonomy_estimator.joblib")

# %%
x_test = X.iloc[:1,:]
x_test
# Out:
#   basemodel  engine_displacement_liters  cylinders make    transmission  \
# 0    Sedona                         3.3        6.0  Kia  Automatic (S6)
#
#   vehicle_size_class
# 0      Minivan - 2WD

# %%
model.predict(x_test)
# Out:
# array([6.91911714])

# %%
data.loc[0,"combined_kmpl_for_fuel_type1"]
# Out:
# np.float64(7.08012)

# %% [markdown]
# ## Saving the dataset

# %%
X["combined_kmpl_for_fuel_type1"] = Y
# Out:
# C:\Users\Emmanuel\AppData\Local\Temp\ipykernel_4144\490778935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["combined_kmpl_for_fuel_type1"] = Y

# %%
X.sample(20).to_parquet("../../unit_tests/testing_data.parquet", index = False)
